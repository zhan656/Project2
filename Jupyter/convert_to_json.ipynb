# %%
import pandas as pd
import json

# %%
data_df = pd.read_csv('final_data.csv')

# %%
data_df
# Out:
#        Unnamed: 0     ID country  \
# 0               0      0      US
# 1               1      1   Spain
# 2               2      2      US
# 3               3      3      US
# 4               4      4  France
# 5               5      5   Spain
# 6               6      6   Spain
# 7               7      7   Spain
# 8               8      8      US
# 9               9      9      US
# 10             10     10   Italy
# 11             11     11      US
# 12             12     12      US
# 13             13     13  France
# 14             14     14      US
# 15             15     15      US
# 16             16     16      US
# 17             17     17   Spain
# 18             18     18  France
# 19             19     19      US
# 20             20     20      US
# 21             21     21   Spain
# 22             22     22   Spain
# 23             23     23      US
# 24             24     24      US
# 25             25     25      US
# 26             26     26      US
# ...

# %%
#data_df.drop(columns=['Unnamed: 0', 'description'])
data_clean = data_df.drop(['Unnamed: 0', 'description', 'designation', 'variety'], axis=1)

# %%
data_clean
# Out:
#           ID country  points  price            province  \
# 0          0      US      96  235.0          California
# 1          1   Spain      96  110.0      Northern Spain
# 2          2      US      96   90.0          California
# 3          3      US      96   65.0              Oregon
# 4          4  France      95   66.0            Provence
# 5          5   Spain      95   73.0      Northern Spain
# 6          6   Spain      95   65.0      Northern Spain
# 7          7   Spain      95  110.0      Northern Spain
# 8          8      US      95   65.0              Oregon
# 9          9      US      95   60.0          California
# 10        10   Italy      95   80.0  Northeastern Italy
# 11        11      US      95   48.0              Oregon
# 12        12      US      95   48.0              Oregon
# 13        13  France      95   90.0    Southwest France
# 14        14      US      95  185.0              Oregon
# 15        15      US      95   90.0              Oregon
# ...

# %%
#data_json = data_df.to_json()

# %%
#data_json
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
data_clean.to_json('geo_data.json')

# %%
data_clean.to_csv('data_clean.csv',sep=',', index=None)
