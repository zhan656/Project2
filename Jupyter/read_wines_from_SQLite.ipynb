# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
import pandas as pd
import numpy as np

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///db/wine_data.sqlite")

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['wine_db']

# %%
# Assign the demographics class to a variable called `Demographics`
Wine= Base.classes.wine_db

# %%
# Create a session
session = Session(engine)

# %%
# Display the row's columns and data in dictionary format
first_row = session.query(Wine).first()
first_row.__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x1116374e0>,
#  'country': 'US',
#  'description': 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.',
#  'designation': "Martha's Vineyard",
#  'id': 1,
#  'points': 96,
#  'price': 235.0,
#  'province': 'California',
#  'region_1': 'Napa Valley',
#  'variety': 'Cabernet Sauvignon',
#  'winery': 'Heitz'}

# %%
stmnt = session.query(Wine).statement
stmnt.__dict__
# Out:
# {'_Annotated__element': <sqlalchemy.sql.selectable.Select at 0x11522d470; Select object>,
#  '_annotations': {'no_replacement_traverse': True},
#  '_auto_correlate': True,
#  '_bind': None,
#  '_columns': <sqlalchemy.sql.base.ColumnCollection at 0x11522d550>,
#  '_columns_plus_names': [(None,
#    Column('id', INTEGER(), table=<wine_db>, primary_key=True, nullable=False)),
#   (None, Column('country', INTEGER(), table=<wine_db>)),
#   (None, Column('description', TEXT(), table=<wine_db>)),
#   (None, Column('designation', TEXT(), table=<wine_db>)),
#   (None, Column('points', INTEGER(), table=<wine_db>)),
#   (None, Column('price', FLOAT(), table=<wine_db>)),
#   (None, Column('province', TEXT(), table=<wine_db>)),
#   (None, Column('region_1', TEXT(), table=<wine_db>)),
#   (None, Column('variety', TEXT(), table=<wine_db>)),
#   (None, Column('winery', TEXT(), table=<wine_db>))],
#  '_for_update_arg': None,
#  '_from_obj': OrderedSet([Table('wine_db', MetaData(bind=None), Column('id', INTEGER(), table=<wine_db>, primary_key=True, nullable=False), Column('country', INTEGER(), table=<wine_db>), Column('description', TEXT(), table=<wine_db>), Column('designation', TEXT(), table=<wine_db>), Column('points', INTEGER(), table=<wine_db>), Column('price', FLOAT(), table=<wine_db>), Column('province', TEXT(), table=<wine_db>), Column('region_1', TEXT(), table=<wine_db>), Column('variety', TEXT(), table=<wine_db>), Column('winery', TEXT(), table=<wine_db>), schema=None)]),
#  '_hash': 290598215,
#  '_having': None,
#  '_raw_columns': [Column('id', INTEGER(), table=<wine_db>, primary_key=True, nullable=False),
#   Column('country', INTEGER(), table=<wine_db>),
#   Column('description', TEXT(), table=<wine_db>),
#   Column('designation', TEXT(), table=<wine_db>),
#   Column('points', INTEGER(), table=<wine_db>),
#   Column('price', FLOAT(), table=<wine_db>),
#   Column('province', TEXT(), table=<wine_db>),
#   Column('region_1', TEXT(), table=<wine_db>),
#   Column('variety', TEXT(), table=<wine_db>),
#   Column('winery', TEXT(), table=<wine_db>)],
#  '_whereclause': None,
#  'columns': <sqlalchemy.sql.base.ImmutableColumnCollection at 0x115234cf0>,
#  'foreign_keys': set(),
#  'primary_key': ColumnSet([Column('id', INTEGER(), table=<Select object>, primary_key=True, nullable=False)]),
#  'use_labels': False}

# %%
df = pd.read_sql_query(stmnt, session.bind)
df[:5]
# Out:
#    id country                                        description  \
# 0   1      US  This tremendous 100% varietal wine hails from ...
# 1   2   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2   3      US  Mac Watson honors the memory of a wine once ma...
# 3   4      US  This spent 20 months in 30% new French oak, an...
# 4   5  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1             variety                   winery
# 0        Napa Valley  Cabernet Sauvignon                    Heitz
# 1               Toro       Tinta de Toro  Bodega Carmen Rodríguez
# 2     Knights Valley     Sauvignon Blanc                 Macauley
# 3  Willamette Valley          Pinot Noir                    Ponzi
# 4             Bandol  Provence red blend     Domaine de la Bégude

# %%
df.set_index('id', inplace=True)
df[:5]
# Out:
#    country                                        description  \
# id
# 1       US  This tremendous 100% varietal wine hails from ...
# 2    Spain  Ripe aromas of fig, blackberry and cassis are ...
# 3       US  Mac Watson honors the memory of a wine once ma...
# 4       US  This spent 20 months in 30% new French oak, an...
# 5   France  This is the top wine from La Bégude, named aft...
#
#                              designation  points  price        province  \
# id
# 1                      Martha's Vineyard      96  235.0      California
# 2   Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 3          Special Selected Late Harvest      96   90.0      California
# 4                                Reserve      96   65.0          Oregon
# 5                             La Brûlade      95   66.0        Provence
#
#              region_1             variety                   winery
# id
# 1         Napa Valley  Cabernet Sauvignon                    Heitz
# 2                Toro       Tinta de Toro  Bodega Carmen Rodríguez
# 3      Knights Valley     Sauvignon Blanc                 Macauley
# 4   Willamette Valley          Pinot Noir                    Ponzi
# 5              Bandol  Provence red blend     Domaine de la Bégude

# %%
c = session.query(Wine.country).all()
country_names = list(np.ravel(c))

# %%
country_names
# Out:
# ['US',
#  'Spain',
#  'US',
#  'US',
#  'France',
#  'Spain',
#  'Spain',
#  'Spain',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'France',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'US',
#  'Italy',
#  'Italy',
#  'Spain',
#  'Spain',
#  'Italy',
#  'France',
#  'Italy',
#  'Italy',
#  'US',
#  'Italy',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Argentina',
#  'Argentina',
#  'France',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'Italy',
#  'Italy',
#  'France',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'France',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Argentina',
#  'US',
#  'US',
#  'Argentina',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'France',
#  'Spain',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Argentina',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'Argentina',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Italy',
#  'US',
#  'Italy',
#  'France',
#  'France',
#  'France',
#  'France',
#  'US',
#  'US',
#  'France',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'France',
#  'France',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'US',
#  'US',
#  'Italy',
#  'France',
#  'US',
#  'Argentina',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'Italy',
#  'France',
#  'US',
#  'US',
#  'France',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'US',
#  'France',
#  'Spain',
#  'US',
#  'France',
#  'Argentina',
#  'France',
#  'France',
#  'US',
#  'Italy',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'Italy',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'France',
#  'France',
#  'France',
#  'France',
#  'US',
#  'France',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Canada',
#  'Spain',
#  'Italy',
#  'Italy',
#  'Italy',
#  'US',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Spain',
#  'Italy',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Italy',
#  'Italy',
#  'Italy',
#  'US',
#  'Argentina',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'Italy',
#  'France',
#  'France',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Italy',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Canada',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'France',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'France',
#  'France',
#  'France',
#  'France',
#  'US',
#  'Italy',
#  'US',
#  'Spain',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'France',
#  'Australia',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Spain',
#  'US',
#  'France',
#  'US',
#  'US',
#  'France',
#  'France',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'Australia',
#  'Argentina',
#  'France',
#  'US',
#  'France',
#  'Italy',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Canada',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Italy',
#  'US',
#  'Argentina',
#  'Argentina',
#  'US',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Italy',
#  'Argentina',
#  'Argentina',
#  'Spain',
#  'France',
#  'Argentina',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'France',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'Italy',
#  'France',
#  'Italy',
#  'US',
#  'US',
#  'France',
#  'France',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'Italy',
#  'US',
#  'France',
#  'France',
#  'France',
#  'France',
#  'US',
#  'US',
#  'Italy',
#  'Australia',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'Spain',
#  'France',
#  'France',
#  'US',
#  'France',
#  'US',
#  'Spain',
#  'Spain',
#  'Italy',
#  'Italy',
#  'Spain',
#  'Italy',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'France',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'Italy',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'France',
#  'Argentina',
#  'US',
#  'France',
#  'US',
#  'France',
#  'France',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'France',
#  'US',
#  'France',
#  'Spain',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'Spain',
#  'Italy',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Spain',
#  'Italy',
#  'Australia',
#  'US',
#  'US',
#  'France',
#  'Argentina',
#  'France',
#  'US',
#  'France',
#  'France',
#  'France',
#  'US',
#  'France',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'Argentina',
#  'US',
#  'Argentina',
#  'Argentina',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'US',
#  'France',
#  'US',
#  'US',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Spain',
#  'Italy',
#  'Italy',
#  'US',
#  'France',
#  'US',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Argentina',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'Spain',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'US',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'US',
#  'France',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'France',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'France',
#  'Argentina',
#  'US',
#  'US',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'France',
#  'US',
#  'France',
#  'Italy',
#  'US',
#  'Italy',
#  'US',
#  'Italy',
#  'US',
#  'Spain',
#  'US',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Spain',
#  'Italy',
#  'US',
#  'US',
#  'Spain',
#  'Italy',
#  'US',
#  'France',
#  'France',
#  'US',
#  'France',
#  'Spain',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'France',
#  'US',
#  'France',
#  'US',
#  'US',
#  'France',
#  'US',
#  'France',
#  'US',
#  'US',
#  'France',
#  'Italy',
#  'US',
#  'Spain',
#  'Argentina',
#  'Italy',
#  'Italy',
#  'US',
#  'France',
#  'US',
#  'Argentina',
#  'US',
#  'US',
#  'US',
#  'France',
#  'Italy',
#  'US',
#  'US',
#  'Spain',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'France',
#  'Spain',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Argentina',
#  'US',
#  'Argentina',
#  'US',
#  'France',
#  'France',
#  'France',
#  'France',
#  'US',
#  'US',
#  'Italy',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'France',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'US',
#  'Argentina',
#  'Argentina',
#  'US',
#  'France',
#  'Argentina',
#  'Spain',
#  'US',
#  'France',
#  'Argentina',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'France',
#  'US',
#  'US',
#  'US',
#  'France',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Argentina',
#  'Italy',
#  'Italy',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'France',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'France',
#  'France',
#  'Italy',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Italy',
#  'Italy',
#  'Italy',
#  'US',
#  'Italy',
#  'France',
#  'US',
#  'France',
#  'France',
#  'Italy',
#  'Italy',
#  'Italy',
#  'US',
#  'US',
#  'Spain',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Spain',
#  'US',
#  'France',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  'US',
#  ...]

# %%
sel = [Wine.id, 
           Wine.country,
           Wine.description, 
           Wine.designation,
           Wine.points, 
           Wine.price,
           Wine.province, 
           Wine.region_1,
           Wine.variety, 
           Wine.winery
           ]

# %%
results = session.query(*sel).all()

# %%
wines = []

# %%
for result in results:
        wines.append({
        "ID":result[0],
        "Country":result[1],
        "Description":result[2],
        "Designation":result[3],
        "Points":result[4],
        "Price":result[5],
        "Province":result[6],
        "Region":result[7],
        "Variety":result[8],
        "Winery":result[9]   
        })

# %%
wines[:5]
# Out:
# [{'Country': 'US',
#   'Description': 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.',
#   'Designation': "Martha's Vineyard",
#   'ID': 1,
#   'Points': 96,
#   'Price': 235.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Heitz'},
#  {'Country': 'Spain',
#   'Description': 'Ripe aromas of fig, blackberry and cassis are softened and sweetened by a slathering of oaky chocolate and vanilla. This is full, layered, intense and cushioned on the palate, with rich flavors of chocolaty black fruits and baking spices. A toasty, everlasting finish is heady but ideally balanced. Drink through 2023.',
#   'Designation': 'Carodorum Selección Especial Reserva',
#   'ID': 2,
#   'Points': 96,
#   'Price': 110.0,
#   'Province': 'Northern Spain',
#   'Region': 'Toro',
#   'Variety': 'Tinta de Toro',
#   'Winery': 'Bodega Carmen Rodríguez'},
#  {'Country': 'US',
#   'Description': 'Mac Watson honors the memory of a wine once made by his mother in this tremendously delicious, balanced and complex botrytised white. Dark gold in color, it layers toasted hazelnut, pear compote and orange peel flavors, reveling in the succulence of its 122 g/L of residual sugar.',
#   'Designation': 'Special Selected Late Harvest',
#   'ID': 3,
#   'Points': 96,
#   'Price': 90.0,
#   'Province': 'California',
#   'Region': 'Knights Valley',
#   'Variety': 'Sauvignon Blanc',
#   'Winery': 'Macauley'},
#  {'Country': 'US',
#   'Description': "This spent 20 months in 30% new French oak, and incorporates fruit from Ponzi's Aurora, Abetina and Madrona vineyards, among others. Aromatic, dense and toasty, it deftly blends aromas and flavors of toast, cigar box, blackberry, black cherry, coffee and graphite. Tannins are polished to a fine sheen, and frame a finish loaded with dark chocolate and espresso. Drink now through 2032.",
#   'Designation': 'Reserve',
#   'ID': 4,
#   'Points': 96,
#   'Price': 65.0,
#   'Province': 'Oregon',
#   'Region': 'Willamette Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Ponzi'},
#  {'Country': 'France',
#   'Description': 'This is the top wine from La Bégude, named after the highest point in the vineyard at 1200 feet. It has structure, density and considerable acidity that is still calming down. With 18 months in wood, the wine has developing an extra richness and concentration. Produced by the Tari family, formerly of Château Giscours in Margaux, it is a wine made for aging. Drink from 2020.',
#   'Designation': 'La Brûlade',
#   'ID': 5,
#   'Points': 95,
#   'Price': 66.0,
#   'Province': 'Provence',
#   'Region': 'Bandol',
#   'Variety': 'Provence red blend',
#   'Winery': 'Domaine de la Bégude'}]

# %%
results = session.query(Wine.id, Wine.country, Wine.description, Wine.designation, Wine.points, Wine.price, Wine.province, Wine.region_1, Wine.variety, Wine.winery).all()

# %%
result
# Out:
# (77284,
#  'France',
#  'A perfect salmon shade, with scents of peaches, cherries and toast. It hits the palate with big, ripe, fresh fruit: crisp apples, peaches, cherries and citrus. Concentrated and full, with a tart, fresh back end that lingers into a cherry-vanilla finish.',
#  'Grand Brut Rosé',
#  90,
#  52.0,
#  'Champagne',
#  'Champagne',
#  'Champagne Blend',
#  'Gosset')

# %%
wines
# Out:
# [{'Country': 'US',
#   'Description': 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.',
#   'Designation': "Martha's Vineyard",
#   'ID': 1,
#   'Points': 96,
#   'Price': 235.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Heitz'},
#  {'Country': 'Spain',
#   'Description': 'Ripe aromas of fig, blackberry and cassis are softened and sweetened by a slathering of oaky chocolate and vanilla. This is full, layered, intense and cushioned on the palate, with rich flavors of chocolaty black fruits and baking spices. A toasty, everlasting finish is heady but ideally balanced. Drink through 2023.',
#   'Designation': 'Carodorum Selección Especial Reserva',
#   'ID': 2,
#   'Points': 96,
#   'Price': 110.0,
#   'Province': 'Northern Spain',
#   'Region': 'Toro',
#   'Variety': 'Tinta de Toro',
#   'Winery': 'Bodega Carmen Rodríguez'},
#  {'Country': 'US',
#   'Description': 'Mac Watson honors the memory of a wine once made by his mother in this tremendously delicious, balanced and complex botrytised white. Dark gold in color, it layers toasted hazelnut, pear compote and orange peel flavors, reveling in the succulence of its 122 g/L of residual sugar.',
#   'Designation': 'Special Selected Late Harvest',
#   'ID': 3,
#   'Points': 96,
#   'Price': 90.0,
#   'Province': 'California',
#   'Region': 'Knights Valley',
#   'Variety': 'Sauvignon Blanc',
#   'Winery': 'Macauley'},
#  {'Country': 'US',
#   'Description': "This spent 20 months in 30% new French oak, and incorporates fruit from Ponzi's Aurora, Abetina and Madrona vineyards, among others. Aromatic, dense and toasty, it deftly blends aromas and flavors of toast, cigar box, blackberry, black cherry, coffee and graphite. Tannins are polished to a fine sheen, and frame a finish loaded with dark chocolate and espresso. Drink now through 2032.",
#   'Designation': 'Reserve',
#   'ID': 4,
#   'Points': 96,
#   'Price': 65.0,
#   'Province': 'Oregon',
#   'Region': 'Willamette Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Ponzi'},
#  {'Country': 'France',
#   'Description': 'This is the top wine from La Bégude, named after the highest point in the vineyard at 1200 feet. It has structure, density and considerable acidity that is still calming down. With 18 months in wood, the wine has developing an extra richness and concentration. Produced by the Tari family, formerly of Château Giscours in Margaux, it is a wine made for aging. Drink from 2020.',
#   'Designation': 'La Brûlade',
#   'ID': 5,
#   'Points': 95,
#   'Price': 66.0,
#   'Province': 'Provence',
#   'Region': 'Bandol',
#   'Variety': 'Provence red blend',
#   'Winery': 'Domaine de la Bégude'},
#  {'Country': 'Spain',
#   'Description': 'Deep, dense and pure from the opening bell, this Toro is a winner. Aromas of dark ripe black fruits are cool and moderately oaked. This feels massive on the palate but sensationally balanced. Flavors of blackberry, coffee, mocha and toasty oak finish spicy, smooth and heady. Drink this exemplary Toro through 2023.',
#   'Designation': 'Numanthia',
#   'ID': 6,
#   'Points': 95,
#   'Price': 73.0,
#   'Province': 'Northern Spain',
#   'Region': 'Toro',
#   'Variety': 'Tinta de Toro',
#   'Winery': 'Numanthia'},
#  {'Country': 'Spain',
#   'Description': "Slightly gritty black-fruit aromas include a sweet note of pastry along with a hint of prune. Wall-to-wall saturation ensures that all corners of one's mouth are covered. Flavors of blackberry, mocha and chocolate are highly impressive and expressive, while this settles nicely on a long finish. Drink now through 2024.",
#   'Designation': 'San Román',
#   'ID': 7,
#   'Points': 95,
#   'Price': 65.0,
#   'Province': 'Northern Spain',
#   'Region': 'Toro',
#   'Variety': 'Tinta de Toro',
#   'Winery': 'Maurodos'},
#  {'Country': 'Spain',
#   'Description': 'Lush cedary black-fruit aromas are luxe and offer notes of marzipan and vanilla. This bruiser is massive and tannic on the palate, but still lush and friendly. Chocolate is a key flavor, while baked berry and cassis flavors are hardly wallflowers. On the finish, this is tannic and deep as a sea trench. Drink this saturated black-colored Toro through 2023.',
#   'Designation': 'Carodorum Único Crianza',
#   'ID': 8,
#   'Points': 95,
#   'Price': 110.0,
#   'Province': 'Northern Spain',
#   'Region': 'Toro',
#   'Variety': 'Tinta de Toro',
#   'Winery': 'Bodega Carmen Rodríguez'},
#  {'Country': 'US',
#   'Description': "This re-named vineyard was formerly bottled as deLancellotti. You'll find striking minerality underscoring chunky black fruits. Accents of citrus and graphite comingle, with exceptional midpalate concentration. This is a wine to cellar, though it is already quite enjoyable. Drink now through 2030.",
#   'Designation': 'Silice',
#   'ID': 9,
#   'Points': 95,
#   'Price': 65.0,
#   'Province': 'Oregon',
#   'Region': 'Chehalem Mountains',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Bergström'},
#  {'Country': 'US',
#   'Description': 'The producer sources from two blocks of the vineyard for this wine—one at a high elevation, which contributes bright acidity. Crunchy cranberry, pomegranate and orange peel flavors surround silky, succulent layers of texture that present as fleshy fruit. That delicately lush flavor has considerable length.',
#   'Designation': "Gap's Crown Vineyard",
#   'ID': 10,
#   'Points': 95,
#   'Price': 60.0,
#   'Province': 'California',
#   'Region': 'Sonoma Coast',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Blue Farm'},
#  {'Country': 'Italy',
#   'Description': "Elegance, complexity and structure come together in this drop-dead gorgeous winethat ranks among Italy's greatest whites. It opens with sublime yellow spring flower, aromatic herb and orchard fruit scents. The creamy, delicious palate seamlessly combines juicy white peach, ripe pear and citrus flavors while white almond and savory mineral notes grace the lingering finish.",
#   'Designation': 'Ronco della Chiesa',
#   'ID': 11,
#   'Points': 95,
#   'Price': 80.0,
#   'Province': 'Northeastern Italy',
#   'Region': 'Collio',
#   'Variety': 'Friulano',
#   'Winery': 'Borgo del Tiglio'},
#  {'Country': 'US',
#   'Description': 'From 18-year-old vines, this supple well-balanced effort blends flavors of mocha, cherry, vanilla and breakfast tea. Superbly integrated and delicious even at this early stage, this wine seems destined for a long and savory cellar life. Drink now through 2028.',
#   'Designation': 'Estate Vineyard Wadensvil Block',
#   'ID': 12,
#   'Points': 95,
#   'Price': 48.0,
#   'Province': 'Oregon',
#   'Region': 'Ribbon Ridge',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Patricia Green Cellars'},
#  {'Country': 'US',
#   'Description': 'A standout even in this terrific lineup of 2015 releases from Patricia Green, the Weber opens with a burst of cola and tobacco scents and accents. It continues, subtle and detailed, with flavors of oranges, vanilla, tea and milk chocolate discreetly threaded through ripe blackberry fruit.',
#   'Designation': 'Weber Vineyard',
#   'ID': 13,
#   'Points': 95,
#   'Price': 48.0,
#   'Province': 'Oregon',
#   'Region': 'Dundee Hills',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Patricia Green Cellars'},
#  {'Country': 'France',
#   'Description': 'This wine is in peak condition. The tannins and the secondary flavors dominate this ripe leather-textured wine. The fruit is all there as well: dried berries and hints of black-plum skins. It is a major wine right at the point of drinking with both the mature flavors and the fruit in the right balance.',
#   'Designation': 'Château Montus Prestige',
#   'ID': 14,
#   'Points': 95,
#   'Price': 90.0,
#   'Province': 'Southwest France',
#   'Region': 'Madiran',
#   'Variety': 'Tannat',
#   'Winery': 'Vignobles Brumont'},
#  {'Country': 'US',
#   'Description': "With its sophisticated mix of mineral, acid and tart fruits, this seductive effort pleases from start to finish. Supple and dense, it's got strawberry, blueberry, plum and black cherry, a touch of chocolate, and that underlying streak of mineral. All these elements are in good proportion and finish with an appealing silky texture. It's delicious already, but give it another decade for full enjoyment. Drink now through 2028.",
#   'Designation': 'Grace Vineyard',
#   'ID': 15,
#   'Points': 95,
#   'Price': 185.0,
#   'Province': 'Oregon',
#   'Region': 'Dundee Hills',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Domaine Serene'},
#  {'Country': 'US',
#   'Description': "First made in 2006, this succulent luscious Chardonnay is all about minerality. It's got a rich core of butterscotch and the seemingly endless layers of subtle flavors that biodynamic farming can bring. It spends 18 months on the lees prior to bottling. Drink now through 2028.",
#   'Designation': 'Sigrid',
#   'ID': 16,
#   'Points': 95,
#   'Price': 90.0,
#   'Province': 'Oregon',
#   'Region': 'Willamette Valley',
#   'Variety': 'Chardonnay',
#   'Winery': 'Bergström'},
#  {'Country': 'US',
#   'Description': "This blockbuster, powerhouse of a wine suggests blueberry pie and chocolate as it opens in the glass. On the palate, it's smooth and seductively silky, offering complex cedar, peppercorn and peppery oak seasonings amidst its dense richness. It finishes with finesse and spice.",
#   'Designation': 'Rainin Vineyard',
#   'ID': 17,
#   'Points': 95,
#   'Price': 325.0,
#   'Province': 'California',
#   'Region': 'Diamond Mountain District',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Hall'},
#  {'Country': 'Spain',
#   'Description': 'Nicely oaked blackberry, licorice, vanilla and charred aromas are smooth and sultry. This is an outstanding wine from an excellent year. Forward barrel-spice and mocha flavors adorn core blackberry and raspberry fruit, while this runs long and tastes vaguely chocolaty on the velvety finish. Enjoy this top-notch Tempranillo through 2030.',
#   'Designation': '6 Años Reserva Premium',
#   'ID': 18,
#   'Points': 95,
#   'Price': 80.0,
#   'Province': 'Northern Spain',
#   'Region': 'Ribera del Duero',
#   'Variety': 'Tempranillo',
#   'Winery': 'Valduero'},
#  {'Country': 'France',
#   'Description': 'Coming from a seven-acre vineyard named after the dovecote on the property, this is a magnificent wine. Powered by both fruit tannins and the 28 months of new wood aging, it is darkly rich and with great concentration. As a sign of its pedigree, there is also elegance here, a restraint which is new to this wine. That makes it a wine for long-term aging. Drink from 2022.',
#   'Designation': 'Le Pigeonnier',
#   'ID': 19,
#   'Points': 95,
#   'Price': 290.0,
#   'Province': 'Southwest France',
#   'Region': 'Cahors',
#   'Variety': 'Malbec',
#   'Winery': 'Château Lagrézette'},
#  {'Country': 'US',
#   'Description': 'This fresh and lively medium-bodied wine is beautifully crafted, with cherry blossom aromas and tangy acidity. Layered and seductive, it offers a crisp mix of orange peel, cherry, pomegranate and baking spice flavors that are ready for the table or the cellar.',
#   'Designation': "Gap's Crown Vineyard",
#   'ID': 20,
#   'Points': 95,
#   'Price': 75.0,
#   'Province': 'California',
#   'Region': 'Sonoma Coast',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Gary Farrell'},
#  {'Country': 'US',
#   'Description': "Heitz has made this stellar rosé from the rare Grignolino grape since 1961. Ruby grapefruit-red, it's sultry with strawberry, watermelon, orange zest and salty spice flavor, highlighted with vibrant floral aromas.",
#   'Designation': 'Grignolino',
#   'ID': 21,
#   'Points': 95,
#   'Price': 24.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Rosé',
#   'Winery': 'Heitz'},
#  {'Country': 'Spain',
#   'Description': 'Alluring, complex and powerful aromas of grilled meat, berries, tea, smoke, vanilla and spice cover every base. An intense palate is concentrated but still elegant. Blackberry, molasses and mocha flavors finish with chocolaty oak notes, fine tannins and overall cohesion. Drink this special Rioja from 2020 through 2035.',
#   'Designation': 'Prado Enea Gran Reserva',
#   'ID': 22,
#   'Points': 95,
#   'Price': 79.0,
#   'Province': 'Northern Spain',
#   'Region': 'Rioja',
#   'Variety': 'Tempranillo Blend',
#   'Winery': 'Muga'},
#  {'Country': 'Spain',
#   'Description': 'Tarry blackberry and cheesy oak aromas are appropriate for a wine of this size and magnitude. In the mouth, this Tinta de Toro is expansive and grabby, with bullish tannins. Slightly salty earthy accents come with core blackberry flavors and notes of baking spices and chocolate, while on the finish this is long, chocolaty, delicious and not too hard or tannic. Drink through 2023.',
#   'Designation': 'Termanthia',
#   'ID': 23,
#   'Points': 95,
#   'Price': 220.0,
#   'Province': 'Northern Spain',
#   'Region': 'Toro',
#   'Variety': 'Tinta de Toro',
#   'Winery': 'Numanthia'},
#  {'Country': 'US',
#   'Description': "The apogee of this ambitious winery's white wine efforts, this bottling of just two barrels of Clone 5 shows focused marzipan, marcona almond and white peach notes on the nose. The palate sizzles with saltiness and a lemony acidity that cuts through its brown butter richness with finesse. The finish is luxurious and long.",
#   'Designation': 'Giallo Solare',
#   'ID': 24,
#   'Points': 95,
#   'Price': 60.0,
#   'Province': 'California',
#   'Region': 'Edna Valley',
#   'Variety': 'Chardonnay',
#   'Winery': 'Center of Effort'},
#  {'Country': 'US',
#   'Description': 'San Jose-based producer Adam Comartin heads 1,100 feet up into the mountains to source fruit for this tremendous wine, which offers wild cherry, sage, and eucalyptus scents on the nose. Ripe black plum and strawberry fruit lead the palate, followed by acid-driven waves of juniper, pine and bay leaf, finishing with a menthol-like sensation.',
#   'Designation': 'R-Bar-R Ranch',
#   'ID': 25,
#   'Points': 95,
#   'Price': 45.0,
#   'Province': 'California',
#   'Region': 'Santa Cruz Mountains',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Comartin'},
#  {'Country': 'US',
#   'Description': 'Bergström has made a Shea designate since 2003, intent on showcasing a “pretty” style of the vineyard. Here are lovely aromatics, with grape jelly, rose petals and plum in the nose, and a complex run of red fruits in the mouth. Streaks of cola, brown sugar and more come up in a generous finish.',
#   'Designation': 'Shea Vineyard',
#   'ID': 26,
#   'Points': 94,
#   'Price': 62.0,
#   'Province': 'Oregon',
#   'Region': 'Willamette Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Bergström'},
#  {'Country': 'US',
#   'Description': "Focused and dense, this intense wine captures the essence of ripe raspberries. Aged in 50% new French oak, it's got a strong vein of coffee and mocha. The flavors broaden out and penetrate, finishing with highlights of cedar, cinnamon and dark chocolate. Drink now through the 2020s, but decant if you want the full expression.",
#   'Designation': 'Abetina',
#   'ID': 27,
#   'Points': 94,
#   'Price': 105.0,
#   'Province': 'Oregon',
#   'Region': 'Willamette Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Ponzi'},
#  {'Country': 'US',
#   'Description': 'Cranberry, baked rhubarb, anise and crushed slate aromas show on the nose of this always-excellent bottling from the Franscioni family. The palate abounds with energy, driving black raspberry fruit accented with earthy loam, fennel, oregano and juniper through a compellingly round midpalate.',
#   'Designation': "Garys' Vineyard",
#   'ID': 28,
#   'Points': 94,
#   'Price': 60.0,
#   'Province': 'California',
#   'Region': 'Santa Lucia Highlands',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Roar'},
#  {'Country': 'US',
#   'Description': "This standout Rocks District wine brings earth shaking aromas of black-olive brine, tapenade, green olive, stargazer lilies, orange peel and crushed gravel. The smoked meat, charcuterie and blue-fruit flavors don't hold back, bringing a lovely sense of texture and detail. It's an intense wine that completely demands your attention.",
#   'Designation': 'The Funk Estate',
#   'ID': 29,
#   'Points': 94,
#   'Price': 60.0,
#   'Province': 'Washington',
#   'Region': 'Walla Walla Valley (WA)',
#   'Variety': 'Syrah',
#   'Winery': 'Saviah'},
#  {'Country': 'US',
#   'Description': "Steely and perfumed, this wine sees only 20% new French oak, remaining vibrantly fresh. Baked apple and lemon pith veer into grapefruit on the palate, with spiciness to the finish that's both brash and loud.",
#   'Designation': 'Babushka',
#   'ID': 30,
#   'Points': 90,
#   'Price': 37.0,
#   'Province': 'California',
#   'Region': 'Russian River Valley',
#   'Variety': 'Chardonnay',
#   'Winery': 'Zepaltas'},
#  {'Country': 'France',
#   'Description': 'Pale in color, this is nutty in character, with a warm and rounded hint of red fruits. The wine has a soft, while still fresh, aftertaste. It is aged in cellars in Saumur on the Loire river.',
#   'Designation': 'Nonpareil Trésor Rosé Brut',
#   'ID': 31,
#   'Points': 90,
#   'Price': 22.0,
#   'Province': 'France Other',
#   'Region': 'Vin Mousseux',
#   'Variety': 'Sparkling Blend',
#   'Winery': 'Bouvet-Ladubay'},
#  {'Country': 'US',
#   'Description': 'The aromas entice with notes of wet stone, honeysuckle, chamomile and stone fruit. The palate is generous in flavor and feel, showing a fine sense of balance.',
#   'Designation': 'Conner Lee Vineyard',
#   'ID': 32,
#   'Points': 90,
#   'Price': 42.0,
#   'Province': 'Washington',
#   'Region': 'Columbia Valley (WA)',
#   'Variety': 'Chardonnay',
#   'Winery': 'Buty'},
#  {'Country': 'Italy',
#   'Description': 'Forest floor, tilled soil, mature berry and a whiff of new leather combine on this. The ripe palate offers fleshy black cherry, dried aromatic herb and tobacco, while fine-grained tannins give the finish some grip. Drink 2018–2023.',
#   'Designation': 'Riserva',
#   'ID': 33,
#   'Points': 90,
#   'Price': 135.0,
#   'Province': 'Tuscany',
#   'Region': 'Brunello di Montalcino',
#   'Variety': 'Sangiovese',
#   'Winery': 'Carillon'},
#  {'Country': 'Italy',
#   'Description': 'This bright, savory wine delivers aromas and flavors of juicy wild cherry, black raspberry, violet, white pepper and mocha. Polished tannins provide the framework. Enjoy through 2020.',
#   'Designation': 'Riserva',
#   'ID': 34,
#   'Points': 90,
#   'Price': 29.0,
#   'Province': 'Tuscany',
#   'Region': 'Chianti Classico',
#   'Variety': 'Red Blend',
#   'Winery': 'Castello di Monterinaldi'},
#  {'Country': 'Spain',
#   'Description': 'Earthy plum and cherry aromas score points for being clear and direct. The palate on this varietal Mencía is round, smooth and just right. Lightly briny, earthy plum and cherry flavors hold steady on the finish, with a dash of saltiness.',
#   'Designation': 'Amandi',
#   'ID': 35,
#   'Points': 90,
#   'Price': 17.0,
#   'Province': 'Galicia',
#   'Region': 'Ribeira Sacra',
#   'Variety': 'Mencía',
#   'Winery': 'Don Bernardino'},
#  {'Country': 'Spain',
#   'Description': 'This comes across wide and expansive as it lazily exudes oily aromas of hazelnut and toffee. A plump palate is not overly cutting or demanding, while flavors of lightly salted nuts and buttered toast end with toffee and peanut flavors.',
#   'Designation': 'Alfonso Oloroso Seco',
#   'ID': 36,
#   'Points': 90,
#   'Price': 26.0,
#   'Province': 'Andalucia',
#   'Region': 'Jerez',
#   'Variety': 'Palomino',
#   'Winery': 'González Byass'},
#  {'Country': 'Italy',
#   'Description': 'Aromas of dark-skinned berry, rose and wild herb lead the nose. The round, juicy palate doles out ripe black cherry, fleshy raspberry, white pepper and clove while polished tannins provide a smooth, velvety framework. Enjoy through 2019.',
#   'Designation': 'Riserva',
#   'ID': 37,
#   'Points': 90,
#   'Price': 39.0,
#   'Province': 'Tuscany',
#   'Region': 'Chianti Classico',
#   'Variety': 'Red Blend',
#   'Winery': 'Rignana'},
#  {'Country': 'France',
#   'Description': 'Dark in color and in flavor profile, this medium-bodied Cornas boasts aromas and flavors reminiscent of chocolate fudge, espresso and plummy fruit, all framed by soft, dusty tannins. Drink now–2025.',
#   'Designation': 'Coteaux',
#   'ID': 38,
#   'Points': 90,
#   'Price': 69.0,
#   'Province': 'Rhône Valley',
#   'Region': 'Cornas',
#   'Variety': 'Syrah',
#   'Winery': 'Tardieu-Laurent'},
#  {'Country': 'Italy',
#   'Description': 'A blend of 90% Sangiovese and 10% Canaiolo, this opens with aromas of violet, mature plum, espresso and a whiff of forest floor. The firm palate offers dried black cherry, ground pepper, toast and clove while packed, fine-grained tannins provide support. Drink through 2020.',
#   'Designation': 'Vigneto Odoardo Beccari Riserva',
#   'ID': 39,
#   'Points': 90,
#   'Price': 30.0,
#   'Province': 'Tuscany',
#   'Region': 'Chianti Classico',
#   'Variety': 'Red Blend',
#   'Winery': 'Vignavecchia'},
#  {'Country': 'Italy',
#   'Description': 'Sunbaked earth, ripe berry, baking spice and a whiff of menthol meld in the glass. The juicy palate offers red cherry, pomegranate, star anise, mocha and a hint of tobacco alongside fine-grained tannins.',
#   'Designation': 'Poggio alle Mura',
#   'ID': 40,
#   'Points': 90,
#   'Price': 90.0,
#   'Province': 'Tuscany',
#   'Region': 'Brunello di Montalcino',
#   'Variety': 'Sangiovese',
#   'Winery': 'Banfi'},
#  {'Country': 'US',
#   'Description': 'Blended with 9% Malbec, 9% Cabernet Franc and 5% Petit Verdot, this is a perennial classic for the winery, the sister brand of Cuvaison. Juicy in cherry and cassis, it sustains big, pillowy tannins and tar, suggesting more time for the fruit to match up with the structure. Drink through 2020.',
#   'Designation': 'Estate Grown',
#   'ID': 41,
#   'Points': 90,
#   'Price': 60.0,
#   'Province': 'California',
#   'Region': 'Mount Veeder',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Brandlin'},
#  {'Country': 'Italy',
#   'Description': 'This robust red opens with aromas of espresso, plum cake, toast and dark spice. The hearty palate offers blackberry jam, licorice, vanilla and mocha alongside firm fine-grained tannins. A coffee note closes the finish.',
#   'Designation': 'Riserva',
#   'ID': 42,
#   'Points': 90,
#   'Price': 100.0,
#   'Province': 'Tuscany',
#   'Region': 'Brunello di Montalcino',
#   'Variety': 'Sangiovese',
#   'Winery': 'Capanne Ricci'},
#  {'Country': 'France',
#   'Description': "This ripe, full-bodied wine has ripe green fruits that are lifted by lime and made richer by apricot. Still young, with a concentrated structure, it's going to develop into a full, beautifully fruity wine. The name of the wine means the size of a parcel that demands the work of seven men for a day. Drink from 2017.",
#   'Designation': 'Les 7 Hommes',
#   'ID': 43,
#   'Points': 90,
#   'Price': 42.0,
#   'Province': 'Loire Valley',
#   'Region': 'Sancerre',
#   'Variety': 'Sauvignon Blanc',
#   'Winery': 'Cherrier Frères'},
#  {'Country': 'France',
#   'Description': "With its light color and cool feel, this well-balanced wine comes from a parcel of 30-year-old vines. The smoky tannins and intense acidity give a wine that will develop well and slowly. It's still young with its red-berry fruits and fresh aftertaste. Drink from 2018.",
#   'Designation': "L'Inédit",
#   'ID': 44,
#   'Points': 90,
#   'Price': 28.0,
#   'Province': 'Loire Valley',
#   'Region': 'Coteaux du Giennois',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Clement et Florian Berthier'},
#  {'Country': 'US',
#   'Description': 'A blend of Cabernet from Grand Ciel (31%), Ciel du Cheval (30%), Upchurch (28%) and Klipsun (11%) vineyards, wood spice aromas start out up front. The cherry flavors are light and elegant, with the tannins bringing some grip.',
#   'Designation': 'Four Flags',
#   'ID': 45,
#   'Points': 90,
#   'Price': 69.0,
#   'Province': 'Washington',
#   'Region': 'Red Mountain',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'DeLille'},
#  {'Country': 'US',
#   'Description': "While exuberantly fruity, almost tropical on the nose, there's a crystalline edge to this dry Riesling that renders it especially refreshing. It's vibrant and light footed, brightened by a lingering honey note on the finish.",
#   'Designation': 'Reserve',
#   'ID': 46,
#   'Points': 90,
#   'Price': 25.0,
#   'Province': 'New York',
#   'Region': 'Finger Lakes',
#   'Variety': 'Riesling',
#   'Winery': 'Dr. Konstantin Frank'},
#  {'Country': 'US',
#   'Description': 'Cabernet makes up just over half of this blend. Aromas of black cherries, herbs and minerals are followed by plush-feeling dark-fruit flavors and backed by firm tannins. Drink now.',
#   'Designation': 'Final Final',
#   'ID': 47,
#   'Points': 90,
#   'Price': 30.0,
#   'Province': 'Washington',
#   'Region': 'Columbia Valley (WA)',
#   'Variety': 'Cabernet Sauvignon-Syrah',
#   'Winery': 'Efeste'},
#  {'Country': 'Italy',
#   'Description': 'This savory blend of 40% Merlot, 30% Cabernet Sauvignon, 25% Cabernet Franc and 5% Syrah opens with aromas of roasted coffee bean, leather, tobacco and dark woodland berry. The chewy palate offers juicy plum, cassis and clove alongside polished tannins. Drink through 2019.',
#   'Designation': 'Poggio Bestiale',
#   'ID': 48,
#   'Points': 90,
#   'Price': 60.0,
#   'Province': 'Tuscany',
#   'Region': 'Maremma Toscana',
#   'Variety': 'Red Blend',
#   'Winery': 'Fattoria di Magliano'},
#  {'Country': 'Argentina',
#   'Description': 'Concentrated, ripe blackberry and cassis aromas come with peppery spice and cedary oak notes. This is big and generous on the palate, with roasted, well-oaked blackberry flavors. A touch of heat lends sizzle to the finish. Drink through 2020.',
#   'Designation': "The Apple Doesn't Fall Far From The Tree",
#   'ID': 49,
#   'Points': 91,
#   'Price': 30.0,
#   'Province': 'Mendoza Province',
#   'Region': 'Mendoza',
#   'Variety': 'Malbec',
#   'Winery': 'Matias Riccitelli'},
#  {'Country': 'Argentina',
#   'Description': 'Smoky aromas of fresh-cut wood blend with berry and cassis form a welcoming, generous bouquet. This feels lively on the palate, albeit tartaric. Oaky plum, cassis and vanilla flavors finish full and agreeable. Drink through 2019.',
#   'Designation': 'Alegoría Gran Reserva',
#   'ID': 50,
#   'Points': 91,
#   'Price': 25.0,
#   'Province': 'Mendoza Province',
#   'Region': 'Mendoza',
#   'Variety': 'Malbec',
#   'Winery': 'Navarro Correas'},
#  {'Country': 'France',
#   'Description': "L'Homme Mort is a northern extension of the Fourchaume Premier Cru vineyard, so called because this was where a local lord dispensed justice by death. It often produces cooler wines such as this. It is tight, with toasted bread hints and with a strongly tangy character. It does need to develop and shouldn't be drunk before 2018.",
#   'Designation': "L'Homme Mort Premier Cru",
#   'ID': 51,
#   'Points': 91,
#   'Price': 45.0,
#   'Province': 'Burgundy',
#   'Region': 'Chablis',
#   'Variety': 'Chardonnay',
#   'Winery': 'Domaine Chenevières'},
#  {'Country': 'US',
#   'Description': 'Fresh boysenberries and a blueberry sorbet character mix with notes of minty tarragon, dill and hot gravel on the nose of this wine, from an area between Gilroy and Morgan Hill. Peppercorns are prominent on the relatively light palate, along with tobacco, espresso and boysenberry.',
#   'Designation': 'Estate Select',
#   'ID': 52,
#   'Points': 91,
#   'Price': 36.0,
#   'Province': 'California',
#   'Region': 'Santa Clara Valley',
#   'Variety': 'Syrah',
#   'Winery': 'Jason-Stephens'},
#  {'Country': 'France',
#   'Description': 'The steely character of a young Chablis is very apparent in this wine. It is crisp, lemon flavored and with a mineral edge. The wine has a juicy freshness, still young at heart and needing to age. Drink from 2018.',
#   'Designation': 'Fourchaume Premier Cru',
#   'ID': 53,
#   'Points': 91,
#   'Price': 38.0,
#   'Province': 'Burgundy',
#   'Region': 'Chablis',
#   'Variety': 'Chardonnay',
#   'Winery': 'Louis Max'},
#  {'Country': 'US',
#   'Description': "From the producer's monumental Atlas Peak vineyard, this is a tightly wound, solidly constructed mountain Cab, blended with a handful of Petit Verdot. Tobacco, black tea and a sliver of coconut intermingle around a medium-bodied whole that will benefit from cellaring, through 2021.",
#   'Designation': 'Animo',
#   'ID': 54,
#   'Points': 91,
#   'Price': 85.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Michael Mondavi Family Estate'},
#  {'Country': 'US',
#   'Description': 'Big, bold, dark and chewy, this builds upon substantial black-cherry fruit and supporting acids. Still knitting together, it shows highlights of cedar and tobacco, along with thick tannins. Give this a couple more years of bottle age, and drink after 2018.',
#   'Designation': 'Schindler Vineyard',
#   'ID': 55,
#   'Points': 91,
#   'Price': 50.0,
#   'Province': 'Oregon',
#   'Region': 'Eola-Amity Hills',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Panther Creek'},
#  {'Country': 'US',
#   'Description': 'A juiciness of cherry and vanilla spark the opening of this wine, a celebration of the vintage, appellation and in this case, fruit-forwardness of the variety. With a backbone of oak and cedar, it has smooth tannins and medium weight, finishing in mocha chocolate. Drink now through 2022.',
#   'Designation': 'Barrel Select',
#   'ID': 56,
#   'Points': 91,
#   'Price': 60.0,
#   'Province': 'California',
#   'Region': 'Rutherford',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Provenance Vineyards'},
#  {'Country': 'US',
#   'Description': 'Sweetened tannins highlight a depth of chocolate and blackberry in this 100% varietal wine made in small amounts. Soft and juicy, it crafts a balance of richness and density around elegant spicy clove and cinnamon.',
#   'Designation': 'District Collection',
#   'ID': 57,
#   'Points': 91,
#   'Price': 85.0,
#   'Province': 'California',
#   'Region': 'St. Helena',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Raymond'},
#  {'Country': 'US',
#   'Description': 'An elegant blend from different estate vineyards, this widely available cuvée brings sturdy tannins and red currant fruit, highlighted with pretty baking spices. It would be an ideal match for roast duck with an orange sauce.',
#   'Designation': 'Premier Cuvée',
#   'ID': 58,
#   'Points': 91,
#   'Price': 54.0,
#   'Province': 'Oregon',
#   'Region': 'Willamette Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Archery Summit'},
#  {'Country': 'France',
#   'Description': "This wine is bone-dry, although with some age the shock of the acidity has been rounded out by a hint of toast. It's linear, fresh and intensely crisp, with citrus and almond tones. Drink this wine from a good vintage now.",
#   'Designation': "Le Nombre d'Or Brut Nature",
#   'ID': 59,
#   'Points': 91,
#   'Price': 85.0,
#   'Province': 'Champagne',
#   'Region': 'Champagne',
#   'Variety': 'Chardonnay',
#   'Winery': 'Aubry'},
#  {'Country': 'US',
#   'Description': 'Given four months in concrete egg, this is an exotically crisp and textured white, lean and high in acidity with plenty of mouthcoating body to find its balance. Lemon, grapefruit and tangerine are the highlights, finished in refreshing layers of white peach.',
#   'Designation': 'Juliana Vineyard',
#   'ID': 60,
#   'Points': 91,
#   'Price': 38.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Sauvignon Blanc',
#   'Winery': 'B Cellars'},
#  {'Country': 'Italy',
#   'Description': 'Underbrush, smoke, mocha and dark fruit aromas lead the nose and carry over to the ripe palate along with dried black cherry, licorice and clove. Firm, velvety tannins provide the framework. Drink 2018–2028.',
#   'Designation': 'Boscato',
#   'ID': 61,
#   'Points': 91,
#   'Price': 75.0,
#   'Province': 'Piedmont',
#   'Region': 'Barolo',
#   'Variety': 'Nebbiolo',
#   'Winery': 'Bel Colle'},
#  {'Country': 'US',
#   'Description': 'Generous black-cherry fruit anchors this barrel-aged wine that remains tartly acidic, with pretty accents of toast and mocha. Focused, young and fresh, it should drink optimally 2018–2028.',
#   'Designation': 'Aeolian',
#   'ID': 62,
#   'Points': 91,
#   'Price': 42.0,
#   'Province': 'Oregon',
#   'Region': 'Eola-Amity Hills',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Bethel Heights'},
#  {'Country': 'Italy',
#   'Description': 'This hearty red opens with aromas of leafy underbrush, leather, licorice and a hint of menthol. The firm, chewy palate offers ripe wild cherry, raspberry jam, anisette and tobacco. Brooding tannins support the dark flavors. Drink 2019–2029.',
#   'Designation': "del Comune di Serralunga d'Alba",
#   'ID': 63,
#   'Points': 91,
#   'Price': 59.0,
#   'Province': 'Piedmont',
#   'Region': 'Barolo',
#   'Variety': 'Nebbiolo',
#   'Winery': 'Cascina Cucco'},
#  {'Country': 'Italy',
#   'Description': 'Enticing aromas of woodland berry, crushed rose, mint and menthol lead the nose on thisfull-bodied red. Mint carries over to the palate along with wild cherry, red raspberry, kitchen spice and a hint of toast. Assertive tannins and bright acidity hold it all together.',
#   'Designation': 'Bricco Luciani',
#   'ID': 64,
#   'Points': 91,
#   'Price': 85.0,
#   'Province': 'Piedmont',
#   'Region': 'Barolo',
#   'Variety': 'Nebbiolo',
#   'Winery': 'Cascina del Monastero'},
#  {'Country': 'Italy',
#   'Description': 'Aromas of French oak, coconut, vanilla and spiced plum lead the nose on this powerfully structured wine. The oak sensations carry over to the warm palate along with cherry marinated in spirits, licorice and menthol. Bracing, close-grained tannins provide the framework and need time to unwind. Best after 2020.',
#   'Designation': 'Bricco Gattera',
#   'ID': 65,
#   'Points': 91,
#   'Price': 80.0,
#   'Province': 'Piedmont',
#   'Region': 'Barolo',
#   'Variety': 'Nebbiolo',
#   'Winery': 'Cordero di Montezemolo'},
#  {'Country': 'France',
#   'Description': 'This delicious, refreshing wine is textured, tight and mineral, with fruity acidity. Tangy and crisp, it has a tight structure, touches of toast along with apple and citrus flavors. The wine is still young and very tight, so should not be drunk before 2017.',
#   'Designation': 'Montmains Premier Cru',
#   'ID': 66,
#   'Points': 91,
#   'Price': 45.0,
#   'Province': 'Burgundy',
#   'Region': 'Chablis',
#   'Variety': 'Chardonnay',
#   'Winery': 'Domaine Gérard Duplessis'},
#  {'Country': 'US',
#   'Description': 'The first Pinot Noir release from this producer, this is a velvety-smooth, exotic and charming wine, light on the palate despite a concentration of ripe, rich fruit. Kirsch, cherry, raspberry and cinnamon combine to make the wine invitingly lush and plush.',
#   'Designation': 'Bacigalupi Vineyard',
#   'ID': 67,
#   'Points': 91,
#   'Price': 65.0,
#   'Province': 'California',
#   'Region': 'Russian River Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Eleven Eleven'},
#  {'Country': 'US',
#   'Description': 'A red Meritage driven by 73% Cabernet Sauvignon, this structured, full-bodied wine also blends in 19% Merlot, 3% Petit Verdot and 3% Malbec. Blackberry and chocolate accent chalky tannins, with bold hits of black licorice, cassis, pencil and black tea. Drink now through 2020.',
#   'Designation': 'Magnificat',
#   'ID': 68,
#   'Points': 91,
#   'Price': 50.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Meritage',
#   'Winery': 'Franciscan'},
#  {'Country': 'Italy',
#   'Description': 'Aromas of white spring flower, orchard fruit and citrus spill out of the glass. The fun lively palate delivers ripe yellow peach and green apple alongside a foaming mousse.',
#   'Designation': 'Nature',
#   'ID': 69,
#   'Points': 86,
#   'Price': 22.0,
#   'Province': 'Veneto',
#   'Region': 'Prosecco',
#   'Variety': 'Glera',
#   'Winery': 'De Stefani'},
#  {'Country': 'US',
#   'Description': 'A smoky scent and earthy, crisp-apple flavors make this medium-bodied wine a change of pace from the average butterball Chardonnay. It has welcome acidity and a nicely smooth texture.',
#   'Designation': 'Small Lot Blend',
#   'ID': 70,
#   'Points': 86,
#   'Price': 13.0,
#   'Province': 'California',
#   'Region': 'Mendocino County',
#   'Variety': 'Chardonnay',
#   'Winery': 'Parducci'},
#  {'Country': 'France',
#   'Description': 'This is a smooth, soft wine that is full of black fruits and ripe tannins. The Merlot rounds out the rougher edges of the Malbec to give a rich juicy wine that will develop quickly. It is all fruit, generous and ready to drink from 2017.',
#   'Designation': 'Château Beauvillain-Monpezat',
#   'ID': 71,
#   'Points': 86,
#   'Price': 14.0,
#   'Province': 'Southwest France',
#   'Region': 'Cahors',
#   'Variety': 'Malbec-Merlot',
#   'Winery': 'Rigal'},
#  {'Country': 'France',
#   'Description': 'Closer to Bordeaux than is Cahors, this is Malbec with a cooler visage. It has spice and stalky tannins along with plenty of acidity. The wine is bright with red berry fruits and a crisp lightly mineral aftertaste. Drink from 2018.',
#   'Designation': 'Pigmentum',
#   'ID': 72,
#   'Points': 86,
#   'Price': 15.0,
#   'Province': 'Southwest France',
#   'Region': 'Buzet',
#   'Variety': 'Merlot-Malbec',
#   'Winery': 'Georges Vigouroux'},
#  {'Country': 'France',
#   'Description': 'This is a blend of 60% Ugni Blanc and 40% Colombard that gives a deliciously light and refreshing wine. Bright and breezy, it is perfumed, herbal and full of direct citrus flavors. Drink now.',
#   'Designation': 'Pigmentum',
#   'ID': 73,
#   'Points': 86,
#   'Price': 10.0,
#   'Province': 'Southwest France',
#   'Region': 'Côtes de Gascogne',
#   'Variety': 'Ugni Blanc-Colombard',
#   'Winery': 'Georges Vigouroux'},
#  {'Country': 'US',
#   'Description': 'Brambly and herbal, this wine shows bright acidity underlying a full-bodied, incoherently ripe palate of tar, toffee and rich cola notes.',
#   'Designation': 'Stephanie',
#   'ID': 74,
#   'Points': 86,
#   'Price': 50.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Hestan'},
#  {'Country': 'US',
#   'Description': 'This Cabernet Sauvignon-dominant blend boasts leather, tobacco leaf and black pepper flavors, giving it muscle and a rustic edge, the tannins and fruit mellowed with age.',
#   'Designation': "Bella's Blend",
#   'ID': 75,
#   'Points': 86,
#   'Price': 48.0,
#   'Province': 'California',
#   'Region': 'Knights Valley',
#   'Variety': 'Cabernet Sauvignon-Cabernet Franc',
#   'Winery': 'Ehret'},
#  {'Country': 'US',
#   'Description': "Fans of stickies may find pleasure in this bottling, but it is tremendously sweet and oily. Candied honeydew and kiwi scents meet with sweet juniper and pine on the nose. On the palate, it tastes squarely of golden honey. It's soft, unctuous and thick in consistency.",
#   'Designation': 'Tears of Dew Late Harvest',
#   'ID': 76,
#   'Points': 86,
#   'Price': 20.0,
#   'Province': 'California',
#   'Region': 'Paso Robles',
#   'Variety': 'Moscato',
#   'Winery': 'EOS'},
#  {'Country': 'US',
#   'Description': 'Aromas of ripe (leaning almost overripe) apple, melon and orange peel are followed by medium-sweet fruit flavors. It needs more acid to stand it up.',
#   'Designation': 'Tudor Hills Vineyard',
#   'ID': 77,
#   'Points': 86,
#   'Price': 17.0,
#   'Province': 'Washington',
#   'Region': 'Yakima Valley',
#   'Variety': 'Pinot Grigio',
#   'Winery': 'Martinez & Martinez'},
#  {'Country': 'US',
#   'Description': 'This is from a hillside estate vineyard and is entirely barrel fermented, its oak subtle and supportive. Medium bodied and not overripe, it offers honeysuckle aromas and lime and lemon rind flavors.',
#   'Designation': 'Homestead Block',
#   'ID': 78,
#   'Points': 86,
#   'Price': 45.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Chardonnay',
#   'Winery': 'Kuleto Estate'},
#  {'Country': 'Argentina',
#   'Description': 'This copper-tinted rosé of Pinot Noir smells like a rubber gym ball and citrus fruits. A full round bouncy palate brings it around, while dry citrus and stone-fruit flavors show a skins-like quality on a steady finish.',
#   'Designation': 'Terroir Único Pinot Noir',
#   'ID': 79,
#   'Points': 86,
#   'Price': 12.0,
#   'Province': 'Mendoza Province',
#   'Region': 'Tupungato',
#   'Variety': 'Rosé',
#   'Winery': 'Zorzal'},
#  {'Country': 'US',
#   'Description': 'This mountain-grown wine is hugely tannic and oaky, hard to penetrate in its full-bodied ripeness. Smoky oak and currant flavors vie for attention against a backdrop of concentration and power.',
#   'Designation': 'Limited Release Cold Springs Vineyard',
#   'ID': 80,
#   'Points': 86,
#   'Price': 125.0,
#   'Province': 'California',
#   'Region': 'Howell Mountain',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Charles Krug'},
#  {'Country': 'US',
#   'Description': 'Savory apples and pears mingle into lemon and bramble in this slightly earthy off-dry Riesling. Sunny tangerine acidity is easy but bright, leading a delicately sweet finish.',
#   'Designation': 'Castle Hill Vineyard',
#   'ID': 81,
#   'Points': 86,
#   'Price': 25.0,
#   'Province': 'New York',
#   'Region': 'Hudson River Region',
#   'Variety': 'Riesling',
#   'Winery': 'Millbrook'},
#  {'Country': 'Argentina',
#   'Description': 'Aromas of prune, raisin and black plum are full and gritty. A chunky full-bodied palate feels grabby, while this tastes of generic blackberry, burnt coffee and dark chocolate. A steady plump, rubbery finish closes the show.',
#   'Designation': 'Reserva',
#   'ID': 82,
#   'Points': 86,
#   'Price': 15.0,
#   'Province': 'Mendoza Province',
#   'Region': 'Valle de Uco',
#   'Variety': 'Malbec',
#   'Winery': 'Viñalba'},
#  {'Country': 'US',
#   'Description': 'Let this burly, big-boned beauty open to fully enjoy its robust oak and fistfuls of black cherry, the oak showing in terms of toasty, slightly reductive aromas. A smooth texture keeps the wine flowing along a concentrated highway of power and ripeness.',
#   'Designation': 'The Flyer',
#   'ID': 83,
#   'Points': 91,
#   'Price': 59.0,
#   'Province': 'California',
#   'Region': 'Russian River Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'MacPhail'},
#  {'Country': 'US',
#   'Description': 'This small-quantity selection from within the Charles Vineyard was fermented by native yeast, and neither fined nor filtered. It is quite aromatic, full bodied and moderately fruity, and has a nice rounded mouthfeel, generous red-cherry and spice flavors and good structure from acidity and mild tannins. Tart cherry lingers on the finish.',
#   'Designation': 'Charles Vineyard Clone 05',
#   'ID': 84,
#   'Points': 91,
#   'Price': 49.0,
#   'Province': 'California',
#   'Region': 'Anderson Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Foursight'},
#  {'Country': 'US',
#   'Description': 'A deeper salmon color with elegantly lacy bubbles and a slight cloudy appearance, this sparkler by Norm Yost offers dessicated watermelon, dried orange blossoms, yeast, citrus rinds and fresher strawberry notes on the nose. Tart raspberry and yeasty melon show on the palate, which offers a salty component as well as a surprising but nice amount of grip.',
#   'Designation': 'Solomon Hills Vineyard Rosé',
#   'ID': 85,
#   'Points': 91,
#   'Price': 42.0,
#   'Province': 'California',
#   'Region': 'Santa Maria Valley',
#   'Variety': 'Sparkling Blend',
#   'Winery': 'Goat Bubbles'},
#  {'Country': 'US',
#   'Description': "This wine takes time to unravel and reveal itself, rewarding the patient with a wealth of high-toned citrus and elegantly wound, medium-bodied honeyed pear and caramel. Lengthy and complex, it's one to consider aging and allowing to further mellow over time. Drink now through 2021.",
#   'Designation': 'Paris Tasting Commemorative',
#   'ID': 86,
#   'Points': 91,
#   'Price': 93.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Chardonnay',
#   'Winery': 'Grgich Hills'},
#  {'Country': 'US',
#   'Description': "This wine is tasty, tangy and nervy, bringing a very refreshing and appetizing mouthfeel, and wonderful fresh acidity. All of that tang shows good fruitiness too, as the red-cherry and cranberry flavors are vivid and concentrated. It's a versatile wine to drink now or buy by the case to save some bottles for more aging.",
#   'Designation': "Methode a l'Ancienne",
#   'ID': 87,
#   'Points': 91,
#   'Price': 32.0,
#   'Province': 'California',
#   'Region': 'Anderson Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Navarro'},
#  {'Country': 'US',
#   'Description': "Renwood's tiny two-barrel production of its most expensive Zinfandel has aromas like vanilla and coconut and flavors as rich as milk chocolate and strawberry jam. This full-bodied wine is practically a liquid dessert, though it's not overly sweet. It's full-bodied, smooth and broad in texture.",
#   'Designation': 'Grand Wren',
#   'ID': 88,
#   'Points': 90,
#   'Price': 100.0,
#   'Province': 'California',
#   'Region': 'Amador County',
#   'Variety': 'Zinfandel',
#   'Winery': 'Renwood'},
#  {'Country': 'US',
#   'Description': 'This is a thick, chocolatey wine with a side of leather and black pepper that appeals on multiple levels. Full-bodied concentration gives way to a smooth, rounded palate robust in blackberry and vanilla.',
#   'Designation': 'Central Park West Vineyard',
#   'ID': 89,
#   'Points': 90,
#   'Price': 50.0,
#   'Province': 'California',
#   'Region': 'St. Helena',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Trinchero'},
#  {'Country': 'Spain',
#   'Description': 'Aromas of strawberry, currant and spice are good in a subtle, non-pushy way. Fresh and grabby on the palate, this tastes of red fruits, baking spices and cocoa. Drying tannins along with cassis and chocolate flavors push a healthy finish. Drink through 2020.',
#   'Designation': 'Arnegui Reserva',
#   'ID': 90,
#   'Points': 90,
#   'Price': 22.0,
#   'Province': 'Northern Spain',
#   'Region': 'Rioja',
#   'Variety': 'Tempranillo',
#   'Winery': 'Pagos del Rey'},
#  {'Country': 'Italy',
#   'Description': 'Scents of Spanish broom, pineapple, orchard fruit and a saline note meld together in the glass. The focused palate offers mature apple, peach, botanical herb and mineral alongside firm acidity.',
#   'Designation': 'Chianta Bianco',
#   'ID': 91,
#   'Points': 90,
#   'Price': 45.0,
#   'Province': 'Sicily & Sardinia',
#   'Region': 'Etna',
#   'Variety': 'White Blend',
#   'Winery': 'Biondi'},
#  {'Country': 'US',
#   'Description': 'Meaty, smoky aromas and good, high-amplitude fruit flavors give a robust personality to this full-bodied, dry and firmly tannic wine. It will make a good pairing with pasta, roasted birds or grilled meat.',
#   'Designation': 'Cooper Ranch',
#   'ID': 92,
#   'Points': 90,
#   'Price': 26.0,
#   'Province': 'California',
#   'Region': 'Amador County',
#   'Variety': 'Barbera',
#   'Winery': 'Andis'},
#  {'Country': 'US',
#   'Description': 'While Cabernet Sauvignon dominant, all five red Bordeaux varieties are represented here. Dark in color, a combination of black pepper and black-fruit syrup meets earthy and dry tannins. This structured wine needs time. Cellar through 2020.',
#   'Designation': 'Longwood',
#   'ID': 93,
#   'Points': 90,
#   'Price': 30.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Cabernet Sauvignon',
#   'Winery': 'Beaucanon'},
#  {'Country': 'US',
#   'Description': "Quite dark in color, brooding aromas of olallieberry, blackberry, grape soda, plums and concentrated purple flowers appease the nose on this bottling from one of Paso's newly designated appellations. The palate blends licorice, turned earth and eucalyptus with a fresh pomegranate juice flavor.",
#   'Designation': 'Estate',
#   'ID': 94,
#   'Points': 90,
#   'Price': 42.0,
#   'Province': 'California',
#   'Region': 'Adelaida District',
#   'Variety': 'Grenache',
#   'Winery': 'Brecon Estate'},
#  {'Country': 'US',
#   'Description': 'A nose of sour cherry and cranberry meshes with sandalwood and savory herbs on this single-site study by the longtime Paso producer. The palate is overflowing with oregano and other dried garden herbs, laid against a juicy red and purple-fruit frame.',
#   'Designation': 'Mustang Springs',
#   'ID': 95,
#   'Points': 90,
#   'Price': 38.0,
#   'Province': 'California',
#   'Region': 'Adelaida District',
#   'Variety': 'Zinfandel',
#   'Winery': 'Peachy Canyon'},
#  {'Country': 'US',
#   'Description': "Heavy fruit concentration meets thick, velvety tannins in this full-bodied, deeply colored and extremely flavorful wine. It's big enough to pair with big proteins, and concentrated enough to keep improving in the cellar. Best after 2019.",
#   'Designation': 'SMC',
#   'ID': 96,
#   'Points': 90,
#   'Price': 48.0,
#   'Province': 'California',
#   'Region': 'California',
#   'Variety': 'Rhône-style Red Blend',
#   'Winery': 'Three'},
#  {'Country': 'Spain',
# ...
#   'Price': 35.0,
#   'Province': 'California',
#   'Region': 'Santa Cruz Mountains',
#   'Variety': 'Chardonnay',
#   'Winery': 'Wrights Station'},
#  {'Country': 'France',
#   'Description': 'With its 50% Sémillon, this ripe wine has the potential to be rich. It has a perfumed, fruity character at this stage, emphasizing flowery fruits along with citrus. As it develops, it will fill out comfortably. Drink from 2016.',
#   'Designation': 'Cuvée des Conti',
#   'ID': 970,
#   'Points': 88,
#   'Price': 16.0,
#   'Province': 'Southwest France',
#   'Region': 'Bergerac Sec',
#   'Variety': 'Bordeaux-style White Blend',
#   'Winery': 'Château Tour des Gendres'},
#  {'Country': 'France',
#   'Description': 'This rich, full-bodied wine is packed with ripe, dense blackberry and plum flavors. With firm tannins in the background, it is always going to be dark and solid. Produced on a single vineyard by the local cooperative, it could still age and will be best from 2016.',
#   'Designation': 'Château Bazin',
#   'ID': 971,
#   'Points': 88,
#   'Price': 45.0,
#   'Province': 'Southwest France',
#   'Region': 'Côtes du Marmandais',
#   'Variety': 'Red Blend',
#   'Winery': 'Cave du Marmandais'},
#  {'Country': 'Italy',
#   'Description': "Made entirely from the native grape Ciliegiolo, this offers aromas of violet, allspice and wild red berry. The bright palate doles out wild cherry, crushed raspberry and a hint of clove alongside silky tannins and fresh acidity. It's easygoing and made to be enjoyed young.",
#   'Designation': 'Serisè',
#   'ID': 972,
#   'Points': 88,
#   'Price': 22.0,
#   'Province': 'Tuscany',
#   'Region': 'Toscana',
#   'Variety': 'Ciliegiolo',
#   'Winery': 'Cesani'},
#  {'Country': 'Italy',
#   'Description': 'Made entirely with Merlot, this densely extracted wine opens with aromas of toasted oak, black currants and vanilla. The tightly packed palate delivers dried blackberries, tobacco, espresso and licorice alongside raspy wood tannins that leave an astringent finish. It lacks the fruit richness to stand up to the heavy oak influence.',
#   'Designation': 'Poggio ai Merli',
#   'ID': 973,
#   'Points': 88,
#   'Price': 110.0,
#   'Province': 'Tuscany',
#   'Region': 'Toscana',
#   'Variety': 'Merlot',
#   'Winery': 'Castellare di Castellina'},
#  {'Country': 'Italy',
#   'Description': 'A blend of Cabernet Sauvignon, Sangiovese, Merlot and Syrah, this opens with aromas of black currant, pencil shavings, toast and a whiff of pine. Notes of mocha, graphite and anise add depth to the black cherry core alongside chewy but astringent tannins that leave a drying finish. Drink 2016–2018.',
#   'Designation': 'Non Confonditur',
#   'ID': 974,
#   'Points': 88,
#   'Price': 26.0,
#   'Province': 'Tuscany',
#   'Region': 'Toscana',
#   'Variety': 'Red Blend',
#   'Winery': 'Argiano'},
#  {'Country': 'US',
#   'Description': "Black pepper, anise, boysenberry and a bit of juniper combine for a slightly funky, somewhat reductive nose on this blend of 46% Grenache, 23% Petite Sirah, 23% Syrah, 6% Carignane and 2% Mourvèdre. There's an ample amount of blackberry jam and chopped Italian herbs on the palate, with an asphalt character in the midpalate and a somewhat tart finish.",
#   'Designation': 'Hope',
#   'ID': 975,
#   'Points': 88,
#   'Price': 40.0,
#   'Province': 'California',
#   'Region': 'California',
#   'Variety': 'Red Blend',
#   'Winery': 'Aver Family Vineyards'},
#  {'Country': 'US',
#   'Description': 'This super-smooth but hearty red blend made from Grenache, Syrah and Mourvèdre smells smoky, meaty and oaky. It tastes savory and a bit peppery before a good dose of ripe, plummy flavor joins in. It feels full-bodied, and almost soft in texture because of light tannins, but has enough acidity to keep an appetizing balance.',
#   'Designation': 'The Sheriff',
#   'ID': 976,
#   'Points': 88,
#   'Price': 36.0,
#   'Province': 'California',
#   'Region': 'Livermore Valley',
#   'Variety': 'Rhône-style Red Blend',
#   'Winery': 'Vasco Urbano'},
#  {'Country': 'Spain',
#   'Description': 'Easy berry and plum aromas come across clean and pure. This has a staunch mouthfeel with rubbery, pinching tannins. Earthy, ripe berry and plum flavors turn even riper on the back palate and finish, which lingers in a solid state.',
#   'Designation': 'Castillo de Albai Crianza',
#   'ID': 977,
#   'Points': 88,
#   'Price': 15.0,
#   'Province': 'Northern Spain',
#   'Region': 'Rioja',
#   'Variety': 'Tempranillo',
#   'Winery': 'Pagos del Rey'},
#  {'Country': 'US',
#   'Description': "Elegant and compact, it offers appealing flavors that call to mind a cherry popsickle—fruity, with palate-cleansing freshness. The wine does a gentle fade, perhaps more quickly than you'd wish.",
#   'Designation': 'Alloro Vineyard',
#   'ID': 978,
#   'Points': 88,
#   'Price': 60.0,
#   'Province': 'Oregon',
#   'Region': 'Chehalem Mountains',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Torii Mor'},
#  {'Country': 'US',
#   'Description': "Balanced toward the bold side, it's full-bodied and shows aromas of ripe grapes and sage, accompanied by flavors of cherry and plum. Layers of fine tannin give it grip without bitterness. Tasty cherry and baking spice flavors linger on the finish.",
#   'Designation': 'Upstream',
#   'ID': 979,
#   'Points': 88,
#   'Price': 25.0,
#   'Province': 'California',
#   'Region': 'Lodi',
#   'Variety': 'Zinfandel',
#   'Winery': 'Watts'},
#  {'Country': 'US',
#   'Description': "A blend of 73% Petite Sirah with 17% Zinfandel, this is a black, inky wine, as to be expected, from Spring Mountain's longstanding York Creek Vineyard. Dusty, earthy and mouthfilling, it is out and out savory. Tastes of black pepper and gamy oak lead to a lingering finish marked by more peppery spice.",
#   'Designation': 'York Creek Vineyard',
#   'ID': 980,
#   'Points': 88,
#   'Price': 37.0,
#   'Province': 'California',
#   'Region': 'Napa Valley',
#   'Variety': 'Petite Sirah',
#   'Winery': 'Elyse'},
#  {'Country': 'US',
#   'Description': 'Made with organically grown grapes, it features a levity of citrus at its heart, a celebration of crisp grapefruit and lime. Dry and midweight, it has texture and a pleasant, long-lasting finish.',
#   'Designation': 'Preston Vineyards',
#   'ID': 981,
#   'Points': 88,
#   'Price': 25.0,
#   'Province': 'California',
#   'Region': 'Dry Creek Valley',
#   'Variety': 'Sauvignon Blanc',
#   'Winery': 'Horse & Plow'},
#  {'Country': 'US',
#   'Description': 'Racy, zesty aromas of honey and squeezed orange form the nose of this still-tight wine, a blend of 62% Grenache Blanc and 38% Rousanne from a vineyard at the mouth of the Arroyo Seco appellation. The crisp palate offers pear and apple cider flavors with a finish of honeydew melon. A perfect pairing for halibut and shellfish.',
#   'Designation': 'Le Cigare Blanc Beeswax Vineyard',
#   'ID': 982,
#   'Points': 88,
#   'Price': 26.0,
#   'Province': 'California',
#   'Region': 'Arroyo Seco',
#   'Variety': 'Rhône-style White Blend',
#   'Winery': 'Bonny Doon'},
#  {'Country': 'US',
#   'Description': 'Thirst-quenching, lean and tangy, it would make a good match with shucked oysters. It shows lemon and green apple aromas, plus fresh and crisp citrus flavors. Medium in body, the texture is pleasantly lean while the finish is refreshing.',
#   'Designation': 'Estate',
#   'ID': 983,
#   'Points': 88,
#   'Price': 10.0,
#   'Province': 'California',
#   'Region': 'Amador County',
#   'Variety': 'Sauvignon Blanc',
#   'Winery': 'Clos du Lac'},
#  {'Country': 'US',
#   'Description': "There's a burly amount of black fruit and black tea in this estate wine, concentrated and coiled in a tight tannic structure. The fruit tends toward ripe black cherry and even blackberry, the texture is soft and the finish delightfully marked by a touch of chocolate.",
#   'Designation': 'Sexton Hill Vineyard',
#   'ID': 984,
#   'Points': 88,
#   'Price': 42.0,
#   'Province': 'California',
#   'Region': 'Russian River Valley',
#   'Variety': 'Pinot Noir',
#   'Winery': 'Balletto'},
#  {'Country': 'Spain',
#   'Description': "Oak, density and medicinal berry aromas are the three most prominent characteristics on the nose of this carbonic macerated Tempranillo. In the mouth, it's full and a bit grabby. Flavors of smoky oak and hickory vie with black-fruit tastes, while the finish is firm and dry, with residual woodiness.",
#   'Designation': 'Maceración Carbónica',
#   'ID': 985,
#   'Points': 88,
#   'Price': 16.0,
#   'Province': 'Northern Spain',
#   'Region': 'Rioja',
#   'Variety': 'Tempranillo Blend',
#   'Winery': 'Dominio de Berzal'},
#  {'Country': 'Spain',
#   'Description': "Floral, stony red-fruit aromas are the right set up for a tight, almost citric feeling palate. Flavors of cherry and red plum are narrow and quick-hitting, while the finish is bright, juicy and runs on acidity. This demands food; it's raw by itself.",
#   'Designation': "AV14 Clos d'Englora",
#   'ID': 986,
#   'Points': 88,
#   'Price': 30.0,
#   'Province': 'Catalonia',
#   'Region': 'Montsant',
#   'Variety': 'Red Blend',
#   'Winery': 'Cellers Baronia del Montsant'},
#  {'Country': 'Spain',
#   'Description': 'This modern Rioja opens with sweet, jammy, raisiny aromas and spice. The palate is cumbersome, with tomatoey acidity providing spine. Baked dark-fruit flavors show a leathery, spicy side, while the finish is full, grabby and tannic, with notes of prune and rubber. 70% Tempranillo and 30% Graciano.',
#   'Designation': 'Inspiración Las Canteras',
#   'ID': 987,
#   'Points': 88,
#   'Price': 25.0,
#   'Province': 'Northern Spain',
#   'Region': 'Rioja',
#   'Variety': 'Tempranillo Blend',
#   'Winery': 'Bodegas Valdemar'},
#  {'Country': 'Spain',
#   'Description': 'Minty, scratchy aromas of cherry and berry air out well. This feels chewy yet fresh in the mouth, with plum and cherry flavors matched by good overall intensity and balance. A controlled finish tastes dusty and loamy; drink through 2017.',
#   'Designation': 'Crianza',
#   'ID': 988,
#   'Points': 88,
#   'Price': 15.0,
#   'Province': 'Northern Spain',
#   'Region': 'Rioja',
#   'Variety': 'Tempranillo Blend',
#   'Winery': 'Viña Herminia'},
#  {'Country': 'US',
#   'Description': 'Brilliant, pure fruit flavors light up this full-bodied but easy-to-drink wine. Cherry, strawberry and something deeper like black currant dance through the aromas and coat the tongue with their richness. The texture is smooth and plush due to fine tannins and mild acidity.',
#   'Designation': 'DuPratt Vineyard Old Vine',
#   'ID': 989,
#   'Points': 90,
#   'Price': 24.0,
#   'Province': 'California',
#   'Region': 'Mendocino Ridge',
#   'Variety': 'Zinfandel',
#   'Winery': 'Steele'},
#  {'Country': 'France',
#   'Description': 'Crisp and young, this wine, from 50-year-old vines, is tangy and strongly mineral in texture. It is full of fresh fruit that reflects the of organic and biodynamic farming. The green fruits will fill out as it ages. Drink from 2017.',
#   'Designation': 'Maison du Villard',
#   'ID': 990,
#   'Points': 90,
#   'Price': 35.0,
#   'Province': 'Burgundy',
#   'Region': 'Pouilly-Fuissé',
#   'Variety': 'Chardonnay',
#   'Winery': 'Château de Lavernette'},
#  {'Country': 'US',
#   'Description': 'Light herb aromas and vivid apple flavors make this medium-bodied wine delicious, while the tangy, nervy texture keeps the mouth tingling. It has great balance, concentration and length on the finish.',
#   'Designation': 'Estate Bottled',
#   'ID': 991,
#   'Points': 90,
#   'Price': 18.0,
#   'Province': 'California',
#   'Region': 'El Dorado',
#   'Variety': 'Sauvignon Blanc',
#   'Winery': 'Lava Cap'},
#  {'Country': 'US',
#   'Description': "This big and dry wine is a nice change of pace. The wine looks dark, smells deep and tastes full bodied and firm textured. It doesn't have the overripe or semisweet character of many Zins, but instead is rather tannic and even mildly astringent like strong tea, and has lip smacking cranberry and raspberry flavors.",
#   'Designation': 'Estate Bottled',
#   'ID': 992,
#   'Points': 90,
#   'Price': 35.0,
#   'Province': 'California',
#   'Region': 'Shenandoah Valley (CA)',
#   'Variety': 'Zinfandel',
#   'Winery': 'Easton'},
#  {'Country': 'US',
#   'Description': 'Quite buttery and nutty on the nose, this wine shows Marcona almonds, seared pineapple, crème brûlée and vanilla custard. Those elements meet with smart amounts of acid and texture on each creamy, buttery, pineapple-laced sip, which then finishes on marshmallow flavors.',
#   'Designation': 'Reserve',
#   'ID': 993,
#   'Points': 90,
#   'Price': 35.0,
#   'Province': 'California',
#   'Region': 'Edna Valley',
#   'Variety': 'Chardonnay',
#   'Winery': 'Edna Valley Vineyard'},
#  {'Country': 'US',
#   'Description': 'Fresh cracked peppercorn, dense black and purple fruit and a cedar tone carry through the nose of this lavish yet nuanced bottling from a South Coast winery that practices extended aging before release. The elderberry fruit is hung on a strong tannic structure, bolstered by woody cigar box, incense, juniper and espresso flavors.',
#   'Designation': 'Erato De Portola Trail Vineyard',
#   'ID': 994,
#   'Points': 90,
#   'Price': 45.0,
#   'Province': 'California',
#   'Region': 'Temecula Valley',
#   'Variety': 'Cabernet Franc',
#   'Winery': 'Gershon Bachus'},
#  {'Country': 'US',
#   'Description': 'Faded yellowish pink in color, this bottling by vintner Richard Sanford and winemaker Nick de Luca shows baking soda, squeezed lemon, sour raspberry and a touch of maraschino cherry on the nose. The palate offers lighter strokes of nectarine and chalky clay notes.',
#   'Designation': 'El Jabali Vineyard Brut Rosé',
#   'ID': 995,
#   'Points': 90,
#   'Price': 65.0,
#   'Province': 'California',
#   'Region': 'Sta. Rita Hills',
#   'Variety': 'Sparkling Blend',
#   'Winery': 'Alma Rosa'},
#  {'Country': 'US',
#   'Description': 'From vines more than 90-years-old, this is a refreshingly restrained and elegant wine, earthy in grilled mushroom and cherry-berry juiciness, braced in firm acidity. Cocoa and nutmeg provide compelling seasonings that linger on the finish.',
#   'Designation': 'Collins Holystone Vineyard Old Vine',
#   'ID': 996,
#   'Points': 90,
#   'Price': 35.0,
#   'Province': 'California',
#   'Region': 'St. Helena',
#   'Variety': 'Zinfandel',
#   'Winery': 'Benessere'},
#  {'Country': 'US',
#   'Description': 'The debut release for this producer is a bright garnet shade. Exhuberant and broad, the palate is bursting with cranberry, blue plum and Bing cherry flavors. Drink over the next year or two, while it is at its freshest.',
#   'Designation': 'Makena',
#   'ID': 997,
#   'Points': 90,
#   'Price': 35.0,
#   'Province': 'Oregon',
#   'Region': 'Eola-Amity Hills',
#   'Variety': 'Pinot Noir',
#   'Winery': 'BKB'},
#  {'Country': 'US',
#   'Description': 'Inviting aromas of baked blueberries are leveled by crushed asphalt and dried herbs on the refined nose of this bottling. Stewed strawberry and red plum flavors are elegantly cut by more crushed stone, dried spearmint and a touch of sweet tobacco, all held together by grippy tannins.',
#   'Designation': 'Mortal Zin',
#   'ID': 998,
#   'Points': 90,
#   'Price': 38.0,
#   'Province': 'California',
#   'Region': 'Paso Robles',
#   'Variety': 'Zinfandel',
#   'Winery': 'Graveyard'},
#  {'Country': 'US',
#   'Description': 'A bit lighter in color than other Rhône blends, certainly due to the 40% Counoise (and bolstered by 36% Mourvèdre and 24% Grenache), this offers a punchy red-currant, orange-rind and chaparral-scrub nose. Fresh cracked black pepper, cranberry-orange-plum juice and a rich earthy tone show on the palate.',
#   'Designation': 'Aatto',
#   'ID': 999,
#   'Points': 90,
#   'Price': 40.0,
#   'Province': 'California',
#   'Region': 'Adelaida District',
#   'Variety': 'Rhône-style Red Blend',
#   'Winery': 'kukkula'},
#  {'Country': 'US',
#   'Description': 'From a former Kosta Browne winemaker comes this very dark Syrah, which shows still-wound-up aromas of elderberry, black coffee, white pepper and a touch of game. There are rich soy and beef notes once sipped, packaged by dense tannins and zesty acidity, with more elderberry, beef char and crushed slate emerging with time. Still young.',
#   'Designation': 'The Villain',
#   'ID': 1000,
#   'Points': 90,
#   'Price': 34.0,
#   'Province': 'California',
#   'Region': 'Santa Lucia Highlands',
#   'Variety': 'Syrah',
#   'Winery': 'Shane Wines'},
#  ...]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-f09fe562337f> in <module>()
# ----> 1 ID
#
# NameError: name 'ID' is not defined
